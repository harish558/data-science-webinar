# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
diction = {'A': 70, 'B': 79, 'C': 91,'D': 85,'E': 34,'F': 62,'G': 56,'H': 84,'I': 92,'J': 78,'K': 45,'L': 68,'M': 71,'N': 52,'O': 31, 'P': 62}

# %%
70+79+91+ 85+ 34+ 62+ 56+ 84+ 92+ 78+ 45+ 68+ 71+ 52+ 31+ 62
# Out:
# 1060

# %%
1060/16
# Out:
# 66.25

# %%
se = pd.Series(diction)

# %%
se.mean(), se.median()
# Out:
# (66.25, 69.0)

# %%
se.describe()
# Out:
# count    16.000000
# mean     66.250000
# std      18.905026
# min      31.000000
# 25%      55.000000
# 50%      69.000000
# 75%      80.250000
# max      92.000000
# dtype: float64

# %%
df = pd.DataFrame(se, columns = ['Marks'])

# %%
df.columns
# Out:
# Index(['Marks'], dtype='object')

# %%
alt.Chart(df).mark_bar().encode(
    x = alt.X('Marks'),
    y = 'count()'
)
# Out:
# alt.Chart(...)

# %%
dem = pd.read_csv('DemographicData.csv')
hw = pd.read_csv('Homework-Data.csv')

# %%
dem.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
hw.head()
# Out:
#            Country Name Country Code        Region  Year  Fertility Rate
# 0                 Aruba          ABW  The Americas  1960           4.820
# 1           Afghanistan          AFG          Asia  1960           7.450
# 2                Angola          AGO        Africa  1960           7.379
# 3               Albania          ALB        Europe  1960           6.186
# 4  United Arab Emirates          ARE   Middle East  1960           6.928

# %%
new_data = pd.merge(dem, hw, on='Country Code')

# %%
new_data.head()
# Out:
#   Country Name_x Country Code  Birth rate  Internet users  \
# 0          Aruba          ABW      10.244            78.9
# 1          Aruba          ABW      10.244            78.9
# 2    Afghanistan          AFG      35.253             5.9
# 3    Afghanistan          AFG      35.253             5.9
# 4         Angola          AGO      45.985            19.1
#
#           Income Group Country Name_y        Region  Year  Fertility Rate
# 0          High income          Aruba  The Americas  1960           4.820
# 1          High income          Aruba  The Americas  2013           1.669
# 2           Low income    Afghanistan          Asia  1960           7.450
# 3           Low income    Afghanistan          Asia  2013           5.050
# 4  Upper middle income         Angola        Africa  1960           7.379

# %%
new_data.drop(['Country Name_y'], axis=1, inplace=True)

# %%
new_data.head()
# Out:
#   Country Name_x Country Code  Birth rate  Internet users  \
# 0          Aruba          ABW      10.244            78.9
# 1          Aruba          ABW      10.244            78.9
# 2    Afghanistan          AFG      35.253             5.9
# 3    Afghanistan          AFG      35.253             5.9
# 4         Angola          AGO      45.985            19.1
#
#           Income Group        Region  Year  Fertility Rate
# 0          High income  The Americas  1960           4.820
# 1          High income  The Americas  2013           1.669
# 2           Low income          Asia  1960           7.450
# 3           Low income          Asia  2013           5.050
# 4  Upper middle income        Africa  1960           7.379

# %%
new_data_2013 = new_data[new_data['Year'] == 2013].copy()

# %%
new_data_2013.head()
# Out:
#          Country Name_x Country Code  Birth rate  Internet users  \
# 1                 Aruba          ABW      10.244            78.9
# 3           Afghanistan          AFG      35.253             5.9
# 5                Angola          AGO      45.985            19.1
# 7               Albania          ALB      12.877            57.2
# 9  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group        Region  Year  Fertility Rate
# 1          High income  The Americas  2013           1.669
# 3           Low income          Asia  2013           5.050
# 5  Upper middle income        Africa  2013           6.165
# 7  Upper middle income        Europe  2013           1.771
# 9          High income   Middle East  2013           1.801

# %%
new_data_2013.drop(['Year'], axis=1, inplace=True)

# %%
new_data_2013.head()
# Out:
#          Country Name_x Country Code  Birth rate  Internet users  \
# 1                 Aruba          ABW      10.244            78.9
# 3           Afghanistan          AFG      35.253             5.9
# 5                Angola          AGO      45.985            19.1
# 7               Albania          ALB      12.877            57.2
# 9  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group        Region  Fertility Rate
# 1          High income  The Americas           1.669
# 3           Low income          Asia           5.050
# 5  Upper middle income        Africa           6.165
# 7  Upper middle income        Europe           1.771
# 9          High income   Middle East           1.801

# %%
cols = list(new_data_2013.columns.values)
cols
# Out:
# ['Country Name_x',
#  'Country Code',
#  'Birth rate',
#  'Internet users',
#  'Income Group',
#  'Region',
#  'Fertility Rate']

# %%
new_data_2013 = new_data_2013[['Country Name_x', 'Country Code', 'Region', 'Birth rate','Internet users', 'Fertility Rate', 'Income Group']]

# %%
new_data_2013.head()
# Out:
#          Country Name_x Country Code        Region  Birth rate  \
# 1                 Aruba          ABW  The Americas      10.244
# 3           Afghanistan          AFG          Asia      35.253
# 5                Angola          AGO        Africa      45.985
# 7               Albania          ALB        Europe      12.877
# 9  United Arab Emirates          ARE   Middle East      11.044
#
#    Internet users  Fertility Rate         Income Group
# 1            78.9           1.669          High income
# 3             5.9           5.050           Low income
# 5            19.1           6.165  Upper middle income
# 7            57.2           1.771  Upper middle income
# 9            88.0           1.801          High income

# %%
cols = list(new_data_2013.columns.values)
cols
# Out:
# ['Country Name_x',
#  'Country Code',
#  'Region',
#  'Birth rate',
#  'Internet users',
#  'Fertility Rate',
#  'Income Group']

# %%
new_data_2013.columns = ['CountryName', 'CountryCode', 'Region', 'BirthRate', 'InternetUsers', 'FertilityRate', 'IncomeGroup']

# %%
new_data_2013.head()
# Out:
#             CountryName CountryCode        Region  BirthRate  InternetUsers  \
# 1                 Aruba         ABW  The Americas     10.244           78.9
# 3           Afghanistan         AFG          Asia     35.253            5.9
# 5                Angola         AGO        Africa     45.985           19.1
# 7               Albania         ALB        Europe     12.877           57.2
# 9  United Arab Emirates         ARE   Middle East     11.044           88.0
#
#    FertilityRate          IncomeGroup
# 1          1.669          High income
# 3          5.050           Low income
# 5          6.165  Upper middle income
# 7          1.771  Upper middle income
# 9          1.801          High income

# %%
new_data_2013.to_csv('./demographic_data.csv', index=False)

# %%
d = {
    'Country': [
        'Canada',
        'France',
        'Germany',
        'Italy',
        'Japan',
        'United Kingdom',
        'United States',
        'Western Sahara',
        'North Korea'
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523, np.nan, np.nan],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075,
        908900,
        32000000,
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067,
        np.nan,
        120538
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915,
        np.nan,
        np.nan
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America',
        'Africa',
        'Asia'
    ]
}

# %%
df = pd.DataFrame.from_dict(d)

# %%
df
# Out:
#           Country  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387     9984670.0  0.913   America
# 1          France      63.951   2833687      640679.0  0.888    Europe
# 2         Germany      80.940   3874437      357114.0  0.916    Europe
# 3           Italy      60.665   2167744      301336.0  0.873    Europe
# 4           Japan     127.061   4602367      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039      242495.0  0.907    Europe
# 6   United States     318.523  17348075     9525067.0  0.915   America
# 7  Western Sahara         NaN    908900           NaN    NaN    Africa
# 8     North Korea         NaN  32000000      120538.0    NaN      Asia

# %%
df.to_csv('economic_indicators.csv', index=None)

# %%
df = pd.read_csv('./demographic_data.csv')

# %%
df.groupby('IncomeGroup').mean()
# Out:
#                      BirthRate  InternetUsers  FertilityRate
# IncomeGroup
# High income          12.589836      74.152833       1.804615
# Low income           37.238267       5.988333       4.984000
# Lower middle income  26.225776      21.871822       3.314306
# Upper middle income  18.943638      40.040844       2.342851

# %%
df.head()
# Out:
#             CountryName CountryCode        Region  BirthRate  InternetUsers  \
# 0                 Aruba         ABW  The Americas     10.244           78.9
# 1           Afghanistan         AFG          Asia     35.253            5.9
# 2                Angola         AGO        Africa     45.985           19.1
# 3               Albania         ALB        Europe     12.877           57.2
# 4  United Arab Emirates         ARE   Middle East     11.044           88.0
#
#    FertilityRate          IncomeGroup
# 0          1.669          High income
# 1          5.050           Low income
# 2          6.165  Upper middle income
# 3          1.771  Upper middle income
# 4          1.801          High income

# %%
df['IncomeGroup'].value_counts()
# Out:
# High income            61
# Lower middle income    49
# Upper middle income    47
# Low income             30
# Name: IncomeGroup, dtype: int64

# %%
df_hi = df[df['IncomeGroup'] == 'High income']

# %%
df_low = df[df['IncomeGroup'] == 'Low income']

# %%
df_lmi = df[df['IncomeGroup'] == 'Lower middle income']

# %%
df_umi = df[df['IncomeGroup'] == 'Upper middle income']

# %%
df_umi.head()
# Out:
#                CountryName CountryCode  Region  BirthRate  InternetUsers  \
# 2                   Angola         AGO  Africa     45.985        19.1000
# 3                  Albania         ALB  Europe     12.877        57.2000
# 10              Azerbaijan         AZE    Asia     18.300        58.7000
# 16                Bulgaria         BGR  Europe      9.200        53.0615
# 19  Bosnia and Herzegovina         BIH  Europe      9.062        57.7900
#
#     FertilityRate          IncomeGroup
# 2           6.165  Upper middle income
# 3           1.771  Upper middle income
# 10          2.000  Upper middle income
# 16          1.500  Upper middle income
# 19          1.272  Upper middle income
